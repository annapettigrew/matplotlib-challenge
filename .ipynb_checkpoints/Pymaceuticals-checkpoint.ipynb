# %% [markdown]
# # Observations and Insights

# %%
# 1 - The Drug Regimens Capomulin and Ramicane seemed to have the greatest effect on Tumor Volume
# 2 - There were slightly more male mice than female mice but the data was close to even
# 3 - The higher the timepoint the lower the tumor volume

# %% [markdown]
# # Pymaceuticals

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# %%
# Adding CSVs
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# %%
# Reading CSVs
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Combining the CSV's
pharm_df = pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID", "Mouse ID"])

# Display
pharm_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Displaying the total number of mice in the dataset
total_mice = len(pharm_df["Mouse ID"])
total_mice
# Out:
# 1893

# %%
# Display the number of unique mice IDs in the data
unique_mice = len(pharm_df["Mouse ID"].unique())
unique_mice
# Out:
# 249

# %%
# Displaying the number of Mice with Duplicate Timepoints 
pharm_df_duplicates = pharm_df[pharm_df.duplicated(["Mouse ID", "Timepoint"])]
pharm_df_duplicates
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID
pharm_df_duplicates_two = pharm_df.set_index('Mouse ID')
pharm_df_duplicates_two.loc['g989']
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
new_pharm_df = pharm_df.drop_duplicates(["Mouse ID", "Timepoint"])
new_pharm_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame
new_mice_count = len(new_pharm_df["Mouse ID"])
new_mice_count
# Out:
# 1888

# %% [markdown]
# # Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
summary_df = new_pharm_df.groupby(['Drug Regimen'])
tumor_mean = summary_df['Tumor Volume (mm3)'].mean()
tumor_median = summary_df['Tumor Volume (mm3)'].median()
tumor_variance = summary_df['Tumor Volume (mm3)'].var()
tumor_sd = summary_df['Tumor Volume (mm3)'].std()
tumor_SEM = summary_df['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame
summary_stat_df = pd.DataFrame({"Mean":tumor_mean,
                               "Median":tumor_median,
                               "Variance":tumor_variance,
                               "Standard Deviation":tumor_sd,
                               "SEM":tumor_SEM})
summary_stat_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803            6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

summary_agg =new_pharm_df.groupby (['Drug Regimen'])['Tumor Volume (mm3)'].agg(['mean','median','var','std','sem'])

summary_agg_df = pd.DataFrame({"Mean":tumor_mean,
                               "Median":tumor_median,
                               "Variance":tumor_variance,
                               "Standard Deviation":tumor_sd,
                               "SEM":tumor_SEM})
summary_agg_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803            6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %% [markdown]
# # Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
bar_df = new_pharm_df.groupby(['Drug Regimen'])['Timepoint'].count()
bar_df.sort_values(ascending=False).plot.bar(color='violet', align='center')
plt.title("Total Timepoints")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.show()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
bar_df_two = bar_df.sort_values(ascending=False)
plt.bar(bar_df_two.index, bar_df_two.values, color='turquoise')
plt.title("Total Timepoints")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.xticks(rotation='vertical')
plt.show()

# %%
 # Generate a pie plot showing the distribution of female versus male mice using Pandas
pie_df = new_pharm_df['Sex'].value_counts()
colors = ['lightblue','pink']
pie_plot = pie_df.plot.pie(startangle=179, explode=(0.1,0), shadow=True, autopct='%1.1f%%', title= 'Male VS Female', colors=colors)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
colors = ['teal','salmon']
pie_df_py = pie_df.plot(kind='pie', y='sex', autopct='%1.1f%%', title='Male VS Female', explode=(0.1,0), shadow=True, colors=colors)

# %% [markdown]
# # Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
great_timepoint = new_pharm_df.groupby(['Mouse ID'])['Timepoint'].last().sort_values()
great_timepoint_df = pd.DataFrame(great_timepoint) 

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
new_great_timepoint = pd.merge(new_pharm_df, great_timepoint_df, on='Mouse ID')
new_great_timepoint
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint_x  \
# 0        k403     Ramicane  Male          21          16            0
# 1        k403     Ramicane  Male          21          16            5
# 2        k403     Ramicane  Male          21          16           10
# 3        k403     Ramicane  Male          21          16           15
# 4        k403     Ramicane  Male          21          16           20
# ...       ...          ...   ...         ...         ...          ...
# 1883     z969     Naftisol  Male           9          30           25
# 1884     z969     Naftisol  Male           9          30           30
# 1885     z969     Naftisol  Male           9          30           35
# 1886     z969     Naftisol  Male           9          30           40
# 1887     z969     Naftisol  Male           9          30           45
#
#       Tumor Volume (mm3)  Metastatic Sites  Timepoint_y
# 0              45.000000                 0           45
# ...

# %%
 # Put treatments into a list for for loop (and later for plot labels)
capomulin = new_pharm_df.loc[new_pharm_df['Drug Regimen'] == 'Capomulin']
ramicane = new_pharm_df.loc[new_pharm_df['Drug Regimen'] == 'Ramicane']
infubinol = new_pharm_df.loc[new_pharm_df['Drug Regimen'] == 'Infubinol']
ceftamin = new_pharm_df.loc[new_pharm_df['Drug Regimen'] == 'Ceftamin']

# list
regimens_list = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_data = []
outliers = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for regimens in regimens_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_mice = new_pharm_df.loc[(new_pharm_df['Drug Regimen'] == regimens)]
    
    # add subset 
    tumor_data.append(new_pharm_df['Tumor Volume (mm3)'])
    outliers.append(new_pharm_df['Tumor Volume (mm3)'])
    
    # Determine outliers using upper and lower bounds
    quartiles = tumor_mice['Tumor Volume (mm3)'].quantile([0.25,0.5,0.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    
    upper_bound = upperq + (1.5*iqr)
    lower_bound = lowerq - (1.5*iqr)
    
    print(f' {regimens}')
    print(f' -------------')
    print(f' The possible Outliers for {regimens} are: {upper_bound}')
    print(f' The possible Outliers for {regimens} are: {lower_bound}')
    print(f' The IQR for {regimens} is: {iqr}')
    print(f' The Upper Quartile for {regimens} is: {upperq}')
    print(f' The Lower Quartile for {regimens} is: {lowerq}')
    print(f' ------------------------------------------------')
# Out:
#  Capomulin
#  -------------
#  The possible Outliers for Capomulin are: 55.9711007025
#  The possible Outliers for Capomulin are: 26.714832162499995
#  The IQR for Capomulin is: 7.314067135000002
#  The Upper Quartile for Capomulin is: 45.0
#  The Lower Quartile for Capomulin is: 37.685932865
#  ------------------------------------------------
#  Ramicane
#  -------------
#  The possible Outliers for Ramicane are: 57.488048122500004
#  The possible Outliers for Ramicane are: 24.1865864625
#  The IQR for Ramicane is: 8.325365415
#  The Upper Quartile for Ramicane is: 45.0
#  The Lower Quartile for Ramicane is: 36.674634585
#  ------------------------------------------------
#  Infubinol
#  -------------
#  The possible Outliers for Infubinol are: 72.31757996875001
#  The possible Outliers for Infubinol are: 32.309217298749985
#  The IQR for Infubinol is: 10.002090667500006
#  The Upper Quartile for Infubinol is: 57.314443967500004
#  The Lower Quartile for Infubinol is: 47.3123533
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
x_cap = capomulin['Tumor Volume (mm3)']
x_ram = ramicane['Tumor Volume (mm3)']
x_inf = infubinol['Tumor Volume (mm3)']
x_cef = ceftamin['Tumor Volume (mm3)']

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interestfig1, ax1 = plt.subplots()
# Capomulin
fig1, ax1 = fig1, ax1 = plt.subplots()
ax1.set_title('Capomulin Regimen')
ax1.set_ylabel("Final Tumor Volume (mm3)")
red_box = dict(markerfacecolor='r',marker='s')
ax1.boxplot(x_cap,flierprops=red_box)
plt.show()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interestfig1, ax1 = plt.subplots()
# Ramicane
fig1, ax1 = plt.subplots()
ax1.set_title('Ramicane Regimen')
ax1.set_ylabel("Final Tumor Volume (mm3)")
red_box = dict(markerfacecolor='r',marker='s')
ax1.boxplot(x_ram,flierprops=red_box)
plt.show()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interestfig1, ax1 = plt.subplots()
# Infubinol
fig1, ax1 = plt.subplots()
ax1.set_title('Infubinol Regimen')
ax1.set_ylabel("Final Tumor Volume (mm3)")
red_box = dict(markerfacecolor='r',marker='s')
ax1.boxplot(x_inf,flierprops=red_box)
plt.show()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interestfig1, ax1 = plt.subplots()
# Ceftamin
fig1, ax1 = plt.subplots()
ax1.set_title('Ceftamin Regimen')
ax1.set_ylabel("Final Tumor Volume (mm3)")
red_box = dict(markerfacecolor='r',marker='s')
ax1.boxplot(x_cef,flierprops=red_box)
plt.show()

# %% [markdown]
# # Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_df = new_pharm_df.set_index('Drug Regimen')
capomulin_df.loc['Capomulin']
# Out:
#              Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin        s185  Female           3          17          0
# Capomulin        s185  Female           3          17          5
# Capomulin        s185  Female           3          17         10
# Capomulin        s185  Female           3          17         15
# Capomulin        s185  Female           3          17         20
# ...               ...     ...         ...         ...        ...
# Capomulin        i557  Female           1          24         45
# Capomulin        r157    Male          22          25          0
# Capomulin        r157    Male          22          25          5
# Capomulin        r157    Male          22          25         10
# Capomulin        r157    Male          22          25         15
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin              45.000000                 0
# Capomulin              43.878496                 0
# ...

# %%
capomulin_mouse = capomulin_df.loc[capomulin_df['Mouse ID'] == "s185"]
capomulin_mouse
# Out:
#              Mouse ID     Sex  Age_months  Weight (g)  Timepoint  \
# Drug Regimen
# Capomulin        s185  Female           3          17          0
# Capomulin        s185  Female           3          17          5
# Capomulin        s185  Female           3          17         10
# Capomulin        s185  Female           3          17         15
# Capomulin        s185  Female           3          17         20
# Capomulin        s185  Female           3          17         25
# Capomulin        s185  Female           3          17         30
# Capomulin        s185  Female           3          17         35
# Capomulin        s185  Female           3          17         40
# Capomulin        s185  Female           3          17         45
#
#               Tumor Volume (mm3)  Metastatic Sites
# Drug Regimen
# Capomulin              45.000000                 0
# Capomulin              43.878496                 0
# Capomulin              37.614948                 0
# ...

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
plt.plot(capomulin_mouse["Timepoint"], capomulin_mouse["Tumor Volume (mm3)"], marker='s', color='olive')
plt.title('Capomulin Mouse')
plt.grid()
plt.xlabel('Timepoint')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_avg = capomulin.groupby('Mouse ID').mean()
plt.scatter(capomulin_avg["Weight (g)"], capomulin_avg['Tumor Volume (mm3)'], color='purple', marker='+')
plt.title("Average Tumor Volume VS Mouse Weight for Capomulin Regimen")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.grid()
plt.show()

# %% [markdown]
# # Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
# linear regression
from scipy.stats import linregress
x_value = capomulin_avg["Weight (g)"]
y_value = capomulin_avg["Tumor Volume (mm3)"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
regression_value = x_value * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_value, y_value, color='gold')
plt.title("Average Tumor Volume VS Mouse Weight for Capomulin Regimen")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.grid()
plt.plot(x_value, regression_value, 'sienna')
plt.annotate(line_eq,(16,45), fontsize=14, color='black')
plt.show()

# %%
# Calculate the correlation coefficient and linear regression model 
# Correlation Coefficient
correlation_coe = round(st.pearsonr(capomulin_avg['Weight (g)'], capomulin_avg['Tumor Volume (mm3)'])[0],2)
print(f'The Correlation Coefficient between Mouse Weight and Average Tumor Volume for the Capomulin Regimen is: {correlation_coe}')
# Out:
# The Correlation Coefficient between Mouse Weight and Average Tumor Volume for the Capomulin Regimen is: 0.84
